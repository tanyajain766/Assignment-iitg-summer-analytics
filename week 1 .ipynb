# %%
# EXPLORE PANDAS

# %%
import pandas as pd

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
movie_users=pd.read_table('http://bit.ly/movieusers' , sep='|', header=None)

# %%
movie_users.head() # there is this pipe seperator  that we need to tell pandas that that we need to seperate it with comma
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
# suppose i want a list of columns names in the movie users

# %%
user_cols=["names","age","gender","occupation","number"]

# %%
movie_users=pd.read_table('http://bit.ly/movieusers' , sep='|', header=None,names=user_cols)

# %%
movie_users.head()
# Out:
#    names  age gender  occupation number
# 0      1   24      M  technician  85711
# 1      2   53      F       other  94043
# 2      3   23      M      writer  32067
# 3      4   24      M  technician  43537
# 4      5   33      F       other  15213

# %%
# suppose that someone has put some text below and above the data file and it is not really needed to skip those we use skip rown and skip footers

# %%
# each of the rows and columns is known as pandas series

# %%
# to extract particular pandas  rows and columns we need

# %%
ufo_reports=pd.read_table('http://bit.ly/uforeports',sep=",")

# %%
ufo_reports.head()
# Out:
#                    city Colors_reported Shape_reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                  Locationn
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo_reports=pd.read_csv('http://bit.ly/uforeports',sep=",") # read _Csv treats comma as default and seperated

# %%
ufo_reports.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_reports['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
# so if we have a  space in column names then we cannot us ufo.

# %%
ufo_reports["Colors Reported"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %%
ufo_reports.shape
# Out:
# (18241, 5)

# %%
ufo_reports['location']= ufo_reports.City +','+ufo_reports.State

# %%
ufo_reports.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
# how do i rename pandas dataframe (columns of pandas)

# %%
ufo_reports.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo_reports.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'location'],
#       dtype='object')

# %%
ufo_reports.rename(columns={'Colors Reported' : 'Colors_reported','Shape Reported':'Shape_reported'}, inplace=True)

# %%
ufo_reports.head()
# Out:
#                    City Colors_reported Shape_reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo_reports_cols=['city','Colors_reported','Shape_reported','State','Time','Locationn']

# %%
ufo_reports.columns=ufo_reports_cols

# %%
ufo_reports.head()
# Out:
#                    city Colors_reported Shape_reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                  Locationn
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo=pd.read_csv("http://bit.ly/uforeports",names=ufo_reports_cols)

# %%
ufo.head()
# Out:
#           city  Colors_reported  Shape_reported  State             Time  \
# 0         City  Colors Reported  Shape Reported  State             Time
# 1       Ithaca              NaN        TRIANGLE     NY   6/1/1930 22:00
# 2  Willingboro              NaN           OTHER     NJ  6/30/1930 20:00
# 3      Holyoke              NaN            OVAL     CO  2/15/1931 14:00
# 4      Abilene              NaN            DISK     KS   6/1/1931 13:00
#
#    Locationn
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# i want to replace the spaces with underscore in case there are spaces in more than 100 names

# %%
ufo.columns=ufo.columns.str.replace(' ','_')

# %%
ufo.columns
# Out:
# Index(['city', 'Colors_reported', 'Shape_reported', 'State', 'Time',
#        'Locationn'],
#       dtype='object')

# %%
ufo.drop(['city','Colors_reported'],axis=1,inplace=True)

# %%
ufo.head()
# Out:
#    Shape_reported  State             Time  Locationn
# 0  Shape Reported  State             Time        NaN
# 1        TRIANGLE     NY   6/1/1930 22:00        NaN
# 2           OTHER     NJ  6/30/1930 20:00        NaN
# 3            OVAL     CO  2/15/1931 14:00        NaN
# 4            DISK     KS   6/1/1931 13:00        NaN

# %%
ufo.drop([0,3],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#   Shape_reported State             Time  Locationn
# 1       TRIANGLE    NY   6/1/1930 22:00        NaN
# 2          OTHER    NJ  6/30/1930 20:00        NaN
# 4           DISK    KS   6/1/1931 13:00        NaN
# 5          LIGHT    NY  4/18/1933 19:00        NaN
# 6           DISK    ND  9/15/1934 15:30        NaN

# %%
ufo.shape
# Out:
# (18240, 4)

# %%
ufo.describe()
# Out:
#        Locationn
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies.sort_values('title') # to sort the whole table according to the title
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
movies.sort_values('duration')
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values(['content_rating','title'])
# Out:
#      star_rating                               title content_rating  \
# 612          7.7                  A Hard Day's Night       APPROVED
# 95           8.4                       All About Eve       APPROVED
# 521          7.8                       Belle de Jour       APPROVED
# 410          7.9                    Bonnie and Clyde       APPROVED
# 285          8.1                    Bringing Up Baby       APPROVED
# ..           ...                                 ...            ...
# 387          8.0                     Midnight Cowboy              X
# 913          7.5                            Suspiria              X
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 936          7.4                           True Grit            NaN
# 649          7.7                   Where Eagles Dare            NaN
#
#          genre  duration                                        actors_list
# ...

# %%
# how to filter rows and columns

# %%
movies[movies.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
booleans=[]
for length in movies.duration:
    if length>=200:
        booleans.append('true')
    else:
        booleans.append('false')

# %%
len(booleans)
# Out:
# 979

# %%
is_long=pd.Series(booleans)
# Out:
# <ipython-input-155-bdaa64760dd8>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   is_long=pd.Series(booleans)

# %%
is_long.head()
# Out:
# Series([], dtype: float64)

# %%
movies[movies.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[movies.duration>=200 and movies.genre=='Crime']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-d93a1d2c3e7e> in <module>
# ----> 1 movies[movies.duration>=200 and movies.genre=='Crime']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
movies[(movies.duration>=200) & (movies.genre =='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
movies[(movies.genre =='Crime')|(movies.genre=='Action')|(movies.genre =='Drama') ]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
movies[movies.genre.isin(['Crime','Action','Drama'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
movies=pd.read_csv('http://bit.ly/imdbratings',usecols=['title','content_rating'])

# %%
movies.head()
# Out:
#                       title content_rating
# 0  The Shawshank Redemption              R
# 1             The Godfather              R
# 2    The Godfather: Part II              R
# 3           The Dark Knight          PG-13
# 4              Pulp Fiction              R

# %%
movies=pd.read_csv('http://bit.ly/imdbratings',usecols=['title','content_rating'],nrows=4)

# %%
movies
# Out:
#                       title content_rating
# 0  The Shawshank Redemption              R
# 1             The Godfather              R
# 2    The Godfather: Part II              R
# 3           The Dark Knight          PG-13

# %%
for c in movies.title:
    print(c)
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight

# %%
# but panda has more to do

# %%
movies.describe(include=['object'])
# Out:
#                 title content_rating
# count               4              4
# unique              4              2
# top     The Godfather              R
# freq                1              3

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop('country',axis=1)
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# 4                             5.9         Africa
# ..                            ...            ...
# ...

# %%
drinks.drop([3,9], axis=0)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 1              Albania             89              132             54
# 2              Algeria             25                0             14
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# ..                 ...            ...              ...            ...
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# ...

# %%
# if i want to drop a particular set of rwos then how can ???

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=1)
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
#         ...
# 188    110.925
# 189     29.000
# 190      1.525
# 191     14.375
# 192     22.675
# Length: 193, dtype: float64

# %%
drinks.mean(axis=0)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis='index')
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis='columns')
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
#         ...
# 188    110.925
# 189     29.000
# 190      1.525
# 191     14.375
# 192     22.675
# Length: 193, dtype: float64

# %%
drinks.drop([1,89],axis=0)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 2              Algeria             25                0             14
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# ..                 ...            ...              ...            ...
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# ...

# %%
orders=pd.read_table('http://bit.ly/chiporders')

# %%
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
orders.choice_description.str.upper()
# Out:
# 0                                                     NaN
# 1                                            [CLEMENTINE]
# 2                                                 [APPLE]
# 3                                                     NaN
# 4       [TOMATILLO-RED CHILI SALSA (HOT), [BLACK BEANS...
#                               ...
# 4617    [FRESH TOMATO SALSA, [RICE, BLACK BEANS, SOUR ...
# 4618    [FRESH TOMATO SALSA, [RICE, SOUR CREAM, CHEESE...
# 4619    [FRESH TOMATO SALSA, [FAJITA VEGETABLES, PINTO...
# 4620    [FRESH TOMATO SALSA, [FAJITA VEGETABLES, LETTU...
# 4621    [FRESH TOMATO SALSA, [FAJITA VEGETABLES, PINTO...
# Name: choice_description, Length: 4622, dtype: object

# %%
orders.choice_description.str.replace('[\[\]]','')
# Out:
# <ipython-input-258-34cbcd74ce54>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   orders.choice_description.str.replace('[\[\]]','')
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks['beer_Servings']=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# beer_Servings                   float64
# dtype: object

# %%
drinks.beer_Servings.str.replace('$','').astype(float).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-265-3bee588bf131> in <module>
# ----> 1 drinks.beer_Servings.str.replace('$','').astype(float).mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=='Africa'].beer_Servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby('continent').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
movies.duration.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-273-e909314a2a49> in <module>
# ----> 1 movies.duration.describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'duration'

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
# %matplotlib inline
movies.duration.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
movies.genre.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
movies.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
# how do I handle missing values

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
# when building the dataframe we see value nan to remove it or replace it with some values

# %%
#let's look ate the method

# %%
ufo.isnull()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# ...      ...              ...             ...    ...    ...
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False
#
# [18241 rows x 5 columns]

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
# this tells the no of missing values of thenull values

# %%
pd.Series([True,  False, True]).sum()
# Out:
# 2

# %%
# is take strue as 1 and false as 0 and then sum

# %%
ufo.City.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18236    False
# 18237    False
# 18238    False
# 18239    False
# 18240    False
# Name: City, Length: 18241, dtype: bool

# %%
ufo[ufo.City.isnull()].count()
# Out:
# City                0
# Colors Reported     5
# Shape Reported     21
# State              25
# Time               25
# dtype: int64

# %%
ufo[ufo.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
# how to drop missing values

# %%
ufo.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-310-d31a6b99b037> in <module>
# ----> 1 ufo.shape()
#
# TypeError: 'tuple' object is not callable

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how='any').shape # only this much row is left in which any of the missing values is present
# Out:
# (2486, 5)

# %%
ufo.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
# how to find values counts

# %%
ufo['Shape Reported'].value_counts(dropna=False) # including the drop values
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# FLARE           1
# HEXAGON         1
# PYRAMID         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].fillna(value='VARIOUS',inplace=True)

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# HEXAGON         1
# PYRAMID         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
 #what do i need to know about pandas index

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  beer_Servings
# 0                           0.0      Asia            0.0
# 1                           4.9    Europe           89.0
# 2                           0.7    Africa           25.0
# 3                          12.4    Europe          245.0
# 4                           5.9    Africa          217.0

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns # it tells the columns name
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent', 'beer_Servings'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 7)

# %%
pd.read_table('http://bit.ly/movieusers',header=None,sep='|'  )
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
drinks[drinks.continent=='South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent  beer_Servings
# 6                             8.3  South America          193.0
# ...

# %%
drinks.loc[23,'beer_Servings']
# Out:
# 245.0

# %%
# loc means location to  find particular row and columns

# %%
drinks.set_index('country',inplace=True)

# %%
drinks.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks.loc['Brazil','beer_Servings']
# Out:
# 245.0

# %%
drinks.index.name=None

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  beer_Servings
# Afghanistan                           0.0      Asia            0.0
# Albania                               4.9    Europe           89.0
# Algeria                               0.7    Africa           25.0
# Andorra                              12.4    Europe          245.0
# Angola                                5.9    Africa          217.0

# %%
drinks.index.name='Country'

# %%
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#        Country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  beer_Servings
# 0                           0.0      Asia            0.0
# 1                           4.9    Europe           89.0
# 2                           0.7    Africa           25.0
# 3                          12.4    Europe          245.0
# 4                           5.9    Africa          217.0

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol  beer_Servings
# count                    193.000000     193.000000
# mean                       4.717098     106.160622
# std                        3.773298     101.143103
# min                        0.000000       0.000000
# 25%                        1.300000      20.000000
# 50%                        4.200000      76.000000
# 75%                        7.200000     188.000000
# max                       14.400000     376.000000

# %%
drinks.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
drinks.columns
# Out:
# Index(['Country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent', 'beer_Servings'],
#       dtype='object')

# %%
drinks.describe().loc['25%','beer_servings']
# Out:
# 20.0

# %%
# what do in need to know about pandas index

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: object

# %%
drinks.set_index('country',inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drinks.continent.value_counts()['Africa']
# Out:
# 53

# %%
drinks.continent.value_counts().sort_index() # index wise sort
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
people=pd.Series([300000,85000],index=['Albania','Andorra'],name='population')

# %%
people
# Out:
# Albania    300000
# Andorra     85000
# Name: population, dtype: int64

# %%
drinks.beer_servings * people # so it matches with country and multiplied
# Out:
# Afghanistan           NaN
# Albania        26700000.0
# Algeria               NaN
# Andorra        20825000.0
# Angola                NaN
#                   ...
# Venezuela             NaN
# Vietnam               NaN
# Yemen                 NaN
# Zambia                NaN
# Zimbabwe              NaN
# Length: 193, dtype: float64

# %%
pd.concat([drinks,people],axis=1).head() # thisis how we can concatinate two pandas series
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe    300000.0
# Algeria                               0.7    Africa         NaN
# Andorra                              12.4    Europe     85000.0
# Angola                                5.9    Africa         NaN

# %%
# how do i select multiple rows and columns in pandas series

# %%
# point out the difference between loc ,iloc  and ix

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# loc is for filtering rows and selecting columns # loc is for selecting things by label

# %%
ufo.loc[0, :]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
# multiple rows

# %%
ufo.loc[[0,1,2],:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:19, :]
# Out:
#                     City Colors Reported Shape Reported State  \
# 0                 Ithaca             NaN       TRIANGLE    NY
# 1            Willingboro             NaN          OTHER    NJ
# 2                Holyoke             NaN           OVAL    CO
# 3                Abilene             NaN           DISK    KS
# 4   New York Worlds Fair             NaN          LIGHT    NY
# 5            Valley City             NaN           DISK    ND
# 6            Crater Lake             NaN         CIRCLE    CA
# 7                   Alma             NaN           DISK    MI
# 8                Eklutna             NaN          CIGAR    AK
# 9                Hubbard             NaN       CYLINDER    OR
# 10               Fontana             NaN          LIGHT    CA
# 11              Waterloo             NaN       FIREBALL    AL
# 12                Belton             RED         SPHERE    SC
# 13                Keokuk             NaN           OVAL    IA
# ...

# %%
ufo.loc[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[1:90,[ 'City','Colors Reported']]
# Out:
#                     City Colors Reported
# 1            Willingboro             NaN
# 2                Holyoke             NaN
# 3                Abilene             NaN
# 4   New York Worlds Fair             NaN
# 5            Valley City             NaN
# ..                   ...             ...
# 86             Henrietta             NaN
# 87          Saranac Lake             NaN
# 88               Proctor             NaN
# 89         Whitmore Lake             NaN
# 90           Kelseyville             NaN
#
# [90 rows x 2 columns]

# %%
ufo.head(3).drop('Time',axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
# use of boolean condition

# %%
ufo.loc[ufo.City=='Alma'].State
# Out:
# 7        MI
# 4296     KS
# 17738    WI
# 17774    NM
# Name: State, dtype: object

# %%
 # using iloc

# %%
ufo.iloc[:,[0,3]]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %%
ufo.iloc[:,0:4]
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
# [18241 rows x 4 columns]

# %%
list(range(0,4))
# Out:
# [0, 1, 2, 3]

# %%
ufo.iloc[: 0:4]
# Out:
# Empty DataFrame
# Columns: [City, Colors Reported, Shape Reported, State, Time]
# Index: []

# %%
ufo.iloc[0:3,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo[['City','State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %%
ufo[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
ufo.iloc[0:3]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry',index_col='country')

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.ix['Albania', 0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-426-8efffb1b2aec> in <module>
# ----> 1 drinks.ix['Albania', 0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
drinks.ix['Albania':'Andorra',0:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-428-0650637f2507> in <module>
# ----> 1 drinks.ix['Albania':'Andorra',0:2]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
# how do i use the inplave parameter in pandas

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1)
# Out:
#       Colors Reported Shape Reported State              Time
# 0                 NaN       TRIANGLE    NY    6/1/1930 22:00
# 1                 NaN          OTHER    NJ   6/30/1930 20:00
# 2                 NaN           OVAL    CO   2/15/1931 14:00
# 3                 NaN           DISK    KS    6/1/1931 13:00
# 4                 NaN          LIGHT    NY   4/18/1933 19:00
# ...               ...            ...   ...               ...
# 18236             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237             NaN           DISK    IA  12/31/2000 23:00
# 18238             NaN            NaN    WI  12/31/2000 23:45
# 18239             RED          LIGHT    WI  12/31/2000 23:45
# 18240             NaN           OVAL    FL  12/31/2000 23:59
#
# [18241 rows x 4 columns]

# %%
ufo.head() # even if we us ethe drop method we cannot remove it from the methodoriginal pandas series
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1).head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1,inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(how='any') # drop the rows if any values is missing
# Out:
#       Colors Reported Shape Reported State              Time
# 12                RED         SPHERE    SC   6/30/1939 20:00
# 19                RED          OTHER    AK   4/30/1943 23:00
# 36                RED      FORMATION    VA    7/10/1945 1:30
# 44              GREEN         SPHERE    CA   6/30/1946 19:00
# 82               BLUE        CHEVRON    CA   7/15/1947 21:00
# ...               ...            ...   ...               ...
# 18213           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220            BLUE           DISK    CA  12/29/2000 20:30
# 18233             RED        VARIOUS    AK  12/31/2000 21:00
# 18239             RED          LIGHT    WI  12/31/2000 23:45
#
# [2490 rows x 4 columns]

# %%
ufo.shape
# Out:
# (18241, 4)

# %%
ufo.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-447-80dd908bb331> in <module>
# ----> 1 ufo.set_index()
#
# TypeError: set_index() missing 1 required positional argument: 'keys'

# %%
ufo.set_index('Time',inplace=True)

# %%
ufo.tail()
# Out:
#                  Colors Reported Shape Reported State
# Time
# 12/31/2000 23:00             NaN       TRIANGLE    IL
# 12/31/2000 23:00             NaN           DISK    IA
# 12/31/2000 23:45             NaN            NaN    WI
# 12/31/2000 23:45             RED          LIGHT    WI
# 12/31/2000 23:59             NaN           OVAL    FL

# %%
ufo.fillna(method='ffill').tail()
# Out:
#                  Colors Reported Shape Reported State
# Time
# 12/31/2000 23:00             RED       TRIANGLE    IL
# 12/31/2000 23:00             RED           DISK    IA
# 12/31/2000 23:45             RED           DISK    WI
# 12/31/2000 23:45             RED          LIGHT    WI
# 12/31/2000 23:59             RED           OVAL    FL

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.Time.str.slice(-5,-3).astype(int).head() # -5 is for the part of which is to be taken starting from 2 and then we have -3
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int32

# %%
ufo['Time']=pd.to_datetime(ufo.Time)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
ufo.Time.dt.hour
# Out:
# 0        22
# 1        20
# 2        14
# 3        13
# 4        19
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: Time, Length: 18241, dtype: int64

# %%
ufo.Time.dt.weekday
# Out:
# 0        6
# 1        0
# 2        6
# 3        0
# 4        1
#         ..
# 18236    6
# 18237    6
# 18238    6
# 18239    6
# 18240    6
# Name: Time, Length: 18241, dtype: int64

# %%
ufo.Time.dt.dayofyear
# Out:
# 0        152
# 1        181
# 2         46
# 3        152
# 4        108
#         ...
# 18236    366
# 18237    366
# 18238    366
# 18239    366
# 18240    366
# Name: Time, Length: 18241, dtype: int64

# %%
ts=pd.to_datetime('1/1/1999')

# %%
ufo.loc[ufo.Time>=ts,:]
# Out:
#                     City Colors Reported Shape Reported State  \
# 12832          Loma Rica             NaN          LIGHT    CA
# 12833            Bauxite             NaN            NaN    AR
# 12834           Florence             NaN       CYLINDER    SC
# 12835       Lake Henshaw             NaN          CIGAR    CA
# 12836  Wilmington Island             NaN          LIGHT    GA
# ...                  ...             ...            ...   ...
# 18236         Grant Park             NaN       TRIANGLE    IL
# 18237        Spirit Lake             NaN           DISK    IA
# 18238        Eagle River             NaN            NaN    WI
# 18239        Eagle River             RED          LIGHT    WI
# 18240               Ybor             NaN           OVAL    FL
#
#                      Time
# 12832 1999-01-01 02:30:00
# 12833 1999-01-01 03:00:00
# 12834 1999-01-01 14:00:00
# 12835 1999-01-01 15:00:00
# 12836 1999-01-01 17:15:00
# ...                   ...
# 18236 2000-12-31 23:00:00
# ...

# %%
ufo.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
(ufo.Time.max()-ufo.Time.min()).days
# Out:
# 25781

# %%
# %matplotlib inline

# %%
ufo['Year']= ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
ufo.Year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
# how do i  find and remove rows and columns (duplocate ones in pandas)

# %%
users=pd.read_table('http://bit.ly/movieusers',sep='|',header=None)

# %%
users
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_cols=['user_id','age','gender','occupation','zip_code']

# %%
users=pd.read_table('http://bit.ly/movieusers',sep='|',header=None,names=user_cols,index_col='user_id')

# %%
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
users.shape
# Out:
# (943, 4)

# %%
users.zip_code.duplicated().sum()
# Out:
# 148

# %%
users.duplicated()
# Out:
# user_id
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 939    False
# 940    False
# 941    False
# 942    False
# 943    False
# Length: 943, dtype: bool

# %%
users.duplicated().sum()
# Out:
# 7

# %%
users.loc[users.duplicated(keep= False), :]
# Out:
#          age gender occupation zip_code
# user_id
# 67        17      M    student    60402
# 85        51      M   educator    20003
# 198       21      F    student    55414
# 350       32      M    student    97301
# 428       28      M    student    55414
# 437       27      F      other    20009
# 460       44      F      other    60630
# 496       21      F    student    55414
# 572       51      M   educator    20003
# 621       17      M    student    60402
# 684       28      M    student    55414
# 733       44      F      other    60630
# 805       27      F      other    20009
# 890       32      M    student    97301

# %%
users.drop_duplicates(keep=False).shape
# Out:
# (929, 4)

# %%
# when you dont want to consider certain columns and not all columns then what

# %%
users.duplicated(subset=['age','zip_code']).sum()
# Out:
# 16

# %%
# how do i avoid setting and copying warnings with pandas

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.content_rating.isnull().sum()
# Out:
# 3

# %%
movies[movies.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
# not rated values ar ethoese whch is none
import numpy as np

# %%
movies[movies.content_rating=='NOT RATED'].content_rating=np.nan
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
movies.content_rating.isnull().sum()
# Out:
# 3

# %%
movies.loc[movies.content_rating=='NOT RATED','content_rating']=np.nan

# %%
movies.content_rating.isnull().sum()
# Out:
# 68

# %%
top_movies=movies.loc[movies.star_rating>=9,:]

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
top_movies.loc[0,'duration']=150
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       150
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
top_movies=movies.loc[movies.star_rating>=9,:].copy()

# %%
top_movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
drinks=pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.head(30)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 1              Albania             89              132             54
# 2              Algeria             25                0             14
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# 7              Armenia             21              179             11
# 8            Australia            261               72            212
# 9              Austria            279               75            191
# 10          Azerbaijan             21               46              5
# 11             Bahamas            122              176             51
# ...

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.set_option('display.max_rows',None)

# %%
drinks
# Out:
#                           country  beer_servings  spirit_servings  \
# 0                     Afghanistan              0                0
# 1                         Albania             89              132
# 2                         Algeria             25                0
# 3                         Andorra            245              138
# 4                          Angola            217               57
# 5               Antigua & Barbuda            102              128
# 6                       Argentina            193               25
# 7                         Armenia             21              179
# 8                       Australia            261               72
# 9                         Austria            279               75
# 10                     Azerbaijan             21               46
# 11                        Bahamas            122              176
# 12                        Bahrain             42               63
# ...

# %%
pd.reset_option('display.max_rows')

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
train=pd.read_csv('http://bit.ly/kaggletrain')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.get_option('display.max_colwidth',1000)
# Out:
# 50

# %%
pd.get_option('display.precision')
# Out:
# 6

# %%
pd.set_option('display.precision',2)

# %%
drinks['y']=drinks.total_litres_of_pure_alcohol*1000

# %%
drinks['x']=drinks.wine_servings*1000

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent        y       x
# 0                           0.0      Asia      0.0       0
# 1                           4.9    Europe   4900.0   54000
# 2                           0.7    Africa    700.0   14000
# 3                          12.4    Europe  12400.0  312000
# 4                           5.9    Africa   5900.0   45000

# %%
pd.set_option('display.float_format','{:,}'.format)

# %%
pd.describe_option('rows')
# Out:
# display.max_info_rows : int or None
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
# display.min_rows : int
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({'id':[100,101,102], 'color':['red','blue','red']},columns=['id','color'],index=['a','b','c'])

# %%
pd.DataFrame([[100,'red'],[101,'blue'],[102,'red']],columns=['id','color'])
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
import numpy as np

# %%
arr= np.random.rand(4,2) # 4,2 NUMPY ARRAY

# %%
arr
# Out:
# array([[0.89868344, 0.55156454],
#        [0.13160241, 0.07061063],
#        [0.63289126, 0.00247847],
#        [0.21738534, 0.81579859]])

# %%
pd.DataFrame(arr,columns=['one','two'])
# Out:
#                   one                   two
# 0  0.8986834370876426    0.5515645446121523
# 1 0.13160240978543025   0.07061063306444537
# 2  0.6328912577372757 0.0024784698092874535
# 3 0.21738533611890087    0.8157985924359457

# %%
pd.DataFrame({'student':np.arange(100,110,1),'test':np.random.randint(60,101,10)}).set_index('student')
# Out:
#          test
# student
# 100        67
# 101        68
# 102        79
# 103        72
# 104       100
# 105        61
# 106        79
# 107        87
# 108        80
# 109        74

# %%
d=pd.Series(['round','square'],index=['c','b'],name='shape')

# %%
pd.concat([df,d],axis=1)
# Out:
#     id color   shape
# a  100   red     NaN
# b  101  blue  square
# c  102   red   round

# %%
train=pd.read_csv('http://bit.ly/kaggletrain')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.0      1
# 2                             Heikkinen, Miss. Laina  female 26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.0      1
# 4                           Allen, Mr. William Henry    male 35.0      0
#
#    Parch            Ticket    Fare Cabin Embarked
# 0      0         A/5 21171    7.25   NaN        S
# 1      0          PC 17599 71.2833   C85        C
# 2      0  STON/O2. 3101282   7.925   NaN        S
# 3      0            113803    53.1  C123        S
# 4      0            373450    8.05   NaN        S

# %%
train['sex_num']=train.Sex.map({'female':0,'male':1})

# %%
train.loc[0:4,['Sex','sex_num']]
# Out:
#       Sex  sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %%
# suppose i want to measure the length of the name

# %%
train['name_length']=train.Name.apply(len)

# %%
train.loc[0:4,{ 'Name','name_length'}]
# Out:
#                                                 Name  name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
import numpy as np

# %%
train['fare_cell']=train.Fare.apply(np.ceil)

# %%
train.loc[0:4,['Fare','fare_cell']]
# Out:
#      Fare  fare_cell
# 0    7.25        8.0
# 1 71.2833       72.0
# 2   7.925        8.0
# 3    53.1       54.0
# 4    8.05        9.0

# %%
train.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
def get_element(my_list,position):
    return my_list(position)

# %%
train.Name.str.split(' ,').apply(get_element,position=0).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-605-66330b19d953> in <module>
# ----> 1 train.Name.str.split(' ,').apply(get_element,position=0).head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in f(x)
#    4121
#    4122             def f(x):
# -> 4123                 return func(x, *args, **kwds)
#    4124
#    4125         else:
#
# <ipython-input-602-48ce86f78906> in get_element(my_list, position)
# ...

# %%
train.Name.str.split(' ,').apply(lambda x:x[0]).head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc[:,'beer_servings':'wine_servings'].apply(np.argmax,axis=1)
# Out:
# 0      0
# 1      1
# 2      0
# 3      2
# 4      0
#       ..
# 188    0
# 189    0
# 190    0
# 191    0
# 192    0
# Length: 193, dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'] = drinks.loc[:,'beer_servings':'wine_servings'].applymap(float)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# multi_indexing# tidy data

# %%
import pandas as pd

# %%
stocks=pd.read_csv('http://bit.ly/smallstocks')

# %%
stocks
# Out:
#          Date  Close    Volume Symbol
# 0  2016-10-03   31.5  14070500   CSCO
# 1  2016-10-03 112.52  21701800   AAPL
# 2  2016-10-03  57.42  19189500   MSFT
# 3  2016-10-04  113.0  29736800   AAPL
# 4  2016-10-04  57.24  20085900   MSFT
# 5  2016-10-04  31.35  18460400   CSCO
# 6  2016-10-05  57.64  16726400   MSFT
# 7  2016-10-05  31.59  11808600   CSCO
# 8  2016-10-05 113.05  21453100   AAPL

# %%
stocks.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
stocks.groupby('Symbol').Close.mean()
# Out:
# Symbol
# AAPL   112.85666666666667
# CSCO                31.48
# MSFT    57.43333333333334
# Name: Close, dtype: float64

# %%
ser=stocks.groupby(['Symbol','Date']).Close.mean()

# %%
ser.index
# Out:
# MultiIndex([('AAPL', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('AAPL', '2016-10-05'),
#             ('CSCO', '2016-10-03'),
#             ('CSCO', '2016-10-04'),
#             ('CSCO', '2016-10-05'),
#             ('MSFT', '2016-10-03'),
#             ('MSFT', '2016-10-04'),
#             ('MSFT', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
ser.unstack()
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52       113.0      113.05
# CSCO          31.5       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
df=stocks.pivot_table(values='Close',index='Symbol',columns='Date')
df
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52       113.0      113.05
# CSCO          31.5       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
ser.loc['AAPL']
# Out:
# Date
# 2016-10-03   112.52
# 2016-10-04    113.0
# 2016-10-05   113.05
# Name: Close, dtype: float64

# %%
ser
# Out:
# Symbol  Date
# AAPL    2016-10-03   112.52
#         2016-10-04    113.0
#         2016-10-05   113.05
# CSCO    2016-10-03     31.5
#         2016-10-04    31.35
#         2016-10-05    31.59
# MSFT    2016-10-03    57.42
#         2016-10-04    57.24
#         2016-10-05    57.64
# Name: Close, dtype: float64

# %%
df.loc['AAPL','2016-10-03']
# Out:
# 112.52

# %%
df.loc[:,'2016-10-03']
# Out:
# Symbol
# AAPL   112.52
# CSCO     31.5
# MSFT    57.42
# Name: 2016-10-03, dtype: float64

# %%
df
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52       113.0      113.05
# CSCO          31.5       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
stocks.set_index(['Symbol','Date'],inplace=True)

# %%
stocks
# Out:
#                    Close    Volume
# Symbol Date
# CSCO   2016-10-03   31.5  14070500
# AAPL   2016-10-03 112.52  21701800
# MSFT   2016-10-03  57.42  19189500
# AAPL   2016-10-04  113.0  29736800
# MSFT   2016-10-04  57.24  20085900
# CSCO   2016-10-04  31.35  18460400
# MSFT   2016-10-05  57.64  16726400
# CSCO   2016-10-05  31.59  11808600
# AAPL   2016-10-05 113.05  21453100

# %%
stocks.index
# Out:
# MultiIndex([('CSCO', '2016-10-03'),
#             ('AAPL', '2016-10-03'),
#             ('MSFT', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('MSFT', '2016-10-04'),
#             ('CSCO', '2016-10-04'),
#             ('MSFT', '2016-10-05'),
#             ('CSCO', '2016-10-05'),
#             ('AAPL', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.title('squares')
plt.xlabel("num")
plt.ylabel("square")
plt.show()

# %%
plt.figure(figsize=(2,5))
plt.plot([1,2,3,4],[1,4,9,16])
plt.axis([0,6,0,20])
plt.annotate('square',(3,6))
plt.show()

# %%
plt.clf
x=np.arange(4)
y=[2.2,3.4,5.5,6.7]
plt.xticks(x,('Ankit','tarun','tanya','hr'))
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
d={'Red O': np.random.rand(10),
   'Grn X':np.random.rand(10)}
df=pd.DataFrame(d)
df.plot(style=['ro','gx'])
plt.show()

# %%
ts=pd.Series(np.random.randn(180),index=pd.date_range('1/1/2018',periods=180))
df=pd.DataFrame(np.random.randn(180,3),index=ts.index,columns=list('ABC'))
df.cumsum.()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-671-718429285d3f> in <module>
#       1 ts=pd.Series(np.random.randn(180),index=pd.date_range('1/1/2018',periods=180))
#       2 df=pd.DataFrame(np.random.randn(180,3),index=ts.index,columns=list('ABC'))
# ----> 3 df.cumsum.show()
#       4 plt.show()
#
# AttributeError: 'function' object has no attribute 'show'

# %%
N=50
x=np.random.randn(N)
y=np.random.randn(N)
colors=np.random.rand(N)
sizes=(30*np.random.rand(N))**2
plt.scatter(x,y,s=sizes,c=colors,alpha=0.5)
plt.show()

# %%
# we will now learn seaborn

# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3,4]
y=[1,2,3,4]

# %%
plt.plot(x,y)

# %%
# seaborn update matplotlib # with graphics (background color ,grid color ,font size)

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x,y)

# %%
car=sns.load_dataset('mpg').dropna() # drop all the null values

# %%
car.shape
# Out:
# (392, 9)

# %%
car.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0 18.0          8         307.0       130.0    3504          12.0          70
# 1 15.0          8         350.0       165.0    3693          11.5          70
# 2 18.0          8         318.0       150.0    3436          11.0          70
# 3 16.0          8         304.0       150.0    3433          12.0          70
# 4 17.0          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
sns.kdeplot(car.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(car.horsepower,shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(car.horsepower,bw=10)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 10 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(car.horsepower,bw=30) # decreasing the bandwidth includes more variances and errors
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 30 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(car.horsepower,cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(car.horsepower,car.cylinders,shade=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(car.horsepower,car.mpg,shade=True,shade_lowest=False)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1676: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.distplot(car.weight,hist=False,rug=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.weight,bins=20)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.weight,bins=[1000,2000,3000,4000,5000])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.horsepower,kde=False,hist_kws={'alpha':1,'histtype' : 'stepfilled'})
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.distplot(car.weight,kde_kws={'lw':5})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.kdeplot(car.weight,lw=5)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.weight,kde_kws={'bw':10})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 10 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.weight,rug=True,rug_kws={'height':0.15})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(car.weight,rug=True,rug_kws={'height':0.15},color='r')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.set_style('whitegrid')

# %% [raw]
# car.cylinder.value_counts()

# %%
car.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
car=car[car.cylinders.isin([4,6,8])]

# %%
car
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393 27.0          4         140.0        86.0    2790          15.6
# 394 44.0          4          97.0        52.0    2130          24.6
# 395 32.0          4         135.0        84.0    2295          11.6
# 396 28.0          4         120.0        79.0    2625          18.6
# 397 31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.boxplot(car.mpg)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
car.mpg.describe()
# Out:
# count                385.0
# mean    23.445454545454545
# std      7.836910953650969
# min                    9.0
# 25%                   17.0
# 50%                   23.0
# 75%                   29.0
# max                   46.6
# Name: mpg, dtype: float64

# %%
sns.boxplot(x=car.origin,y=car.mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=car)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',hue='cylinders',data=car)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
car.model_year.describe()
# Out:
# count               385.0
# mean    75.96103896103897
# std     3.692057771001915
# min                  70.0
# 25%                  73.0
# 50%                  76.0
# 75%                  79.0
# max                  82.0
# Name: model_year, dtype: float64

# %%
# styling options

# %%
sns.boxplot(x='mpg',y='origin',data=car,order=['japan','euorpe','usa'])
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='mpg',y='origin',data=car,linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='mpg',y='origin',data=car,whis=1)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='mpg',y='origin',data=car,fliersize=20)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='mpg',y='origin',data=car,showcaps=False)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
#seaborn violinplot

# %%
#like its name it looks like a voilin

# %%
sns.violinplot(x=car.cylinders,y=car.displacement)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(x='cylinders' ,y='displacement',hue='origin',data=car[car.origin.isin(['japan','europe'])],split=True,scale='count',scale_hue=False)
plt.legend(loc=2)

# %%
diamonds=sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price    x    y    z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326 3.95 3.98 2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326 3.89 3.84 2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327 4.05 4.07 2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.2 4.23 2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335 4.34 4.35 2.75

# %%
diamonds=diamonds[
    diamonds.cut.isin(['premium','Good'])& diamonds.color.isin(['D','F','J'])].sample(n=100 ,random_state=22)
diamonds.shape
# Out:
# (100, 10)

# %%
# scatter plot

# %%
sns.set_style('dark')

# %%
sns.scatterplot(diamonds.carat,diamonds.price)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='x',y='y',data=diamonds)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.set_style('darkgrid')

# %%
sns.scatterplot(x='carat',y='price',data=diamonds,hue='cut')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',hue='depth',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',data=diamonds,s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',size='cut',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',size='cut',data=diamonds,sizes=[100,50])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-812-ca94c4f8e664> in <module>
# ----> 1 sns.scatterplot(x='carat',y='price',size='cut',data=diamonds,sizes=[100,50])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     807
#     808     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# --> 809     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
# ...

# %%
# hue +style+size

# %%
sns.scatterplot(x='carat',y='price',hue='cut',style='color',data=diamonds,s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',data=diamonds,s=1000,alpha=0.6,marker= '*' ,edgecolor='black')
# alpha basically used to see whether there is a n overlap or not as they are trasnparent so one can easily check
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
# lineplot

# %%
# useful in pattern of trends and seasonality

# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-831-dbdff1f201c0> in <module>
# ----> 1 df=pd.read_csv('dataset.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df=pd.read_csv("C:/Users/HP/Desktop/pandas/dataset.csv")

# %%
df.head()
# Out:
#   SystemCodeNumber  Capacity  Occupancy       LastUpdated
# 0      BHMBCCMKT01       577         61  04-10-2016 07:59
# 1      BHMBCCMKT01       577         64  04-10-2016 08:25
# 2      BHMBCCMKT01       577         80  04-10-2016 08:59
# 3      BHMBCCMKT01       577        107  04-10-2016 09:32
# 4      BHMBCCMKT01       577        150  04-10-2016 09:59

# %%
df.rename(columns={"SystemCodeNumber":"Location","LastUpdated":"Timestamp"},inplace=True)

# %%
df['day']=df.Timestamp.dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-857-1cdb303567e2> in <module>
# ----> 1 df['day']=df.Timestamp.dt.date
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
park=df[df.Location.isin(['Broad Street','NIA South'])]

# %%
park.head()
# Out:
#            Location  Capacity  Occupancy         Timestamp
# 20171  Broad Street       690        178  04-10-2016 07:59
# 20172  Broad Street       690        269  04-10-2016 08:25
# 20173  Broad Street       690        415  04-10-2016 08:59
# 20174  Broad Street       690        530  04-10-2016 09:32
# 20175  Broad Street       690        600  04-10-2016 09:59

# %%
# basics

# %%
sns.set_style('dark')

# %%
months=[pd.datetime(2016,10,1),
       pd.datetime(2016,11,1),
       pd.datetime(2016,12,1)]
# Out:
# <ipython-input-863-c812f1d6ca8a>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   months=[pd.datetime(2016,10,1),
# <ipython-input-863-c812f1d6ca8a>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime(2016,11,1),
# <ipython-input-863-c812f1d6ca8a>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime(2016,12,1)]

# %%
plt.rc('date.autoformatter',day= '%b %y')

# %%
sns.lineplot(park.day,park.Occupancy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-869-5fa4694009a6> in <module>
# ----> 1 sns.lineplot(park.day,park.Occupancy)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'day'

# %%
sns.lineplot(x='hour',y='occupancy',data=park,n_boot=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-870-f09d3c516438> in <module>
# ----> 1 sns.lineplot(x='hour',y='occupancy',data=park,n_boot=1000)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     683
#     684     variables = _LinePlotter.get_semantics(locals())
# --> 685     p = _LinePlotter(
#     686         data=data, variables=variables,
# ...

# %%
car=sns.load_dataset('mpg')

# %%
car.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0 18.0          8         307.0       130.0    3504          12.0          70
# 1 15.0          8         350.0       165.0    3693          11.5          70
# 2 18.0          8         318.0       150.0    3436          11.0          70
# 3 16.0          8         304.0       150.0    3433          12.0          70
# 4 17.0          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
car.groupby('origin').cylinders.value_counts()
# Out:
# origin  cylinders
# europe  4             63
#         6              4
#         5              3
# japan   4             69
#         6              6
#         3              4
# usa     8            103
#         6             74
#         4             72
# Name: cylinders, dtype: int64

# %%
car.groupby('origin').cylinders.value_counts().unstack().fillna(0)
# Out:
# cylinders   3    4   5    6     8
# origin
# europe    0.0 63.0 3.0  4.0   0.0
# japan     4.0 69.0 0.0  6.0   0.0
# usa       0.0 72.0 0.0 74.0 103.0

# %%
sns.heatmap(car.cylinders)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-885-b21db2998a41> in <module>
# ----> 1 sns.heatmap(car.cylinders)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
test_numpy=np.array([[1,2],[3,4]])

# %%
test_numpy
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sns.heatmap(test_numpy)
# Out:
# <AxesSubplot:>

# %%
origin_cyl.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-891-a4eb8bbeee89> in <module>
# ----> 1 origin_cyl.T
#
# NameError: name 'origin_cyl' is not defined

# %%
car.corr()
# Out:
#                              mpg            cylinders        displacement  \
# mpg                          1.0  -0.7753962854205539 -0.8042028248058979
# cylinders    -0.7753962854205539                  1.0  0.9507213901392415
# displacement -0.8042028248058979   0.9507213901392415                 1.0
# horsepower   -0.7784267838977761   0.8429833569186568    0.89725700184347
# weight       -0.8317409332443344   0.8960167954533944   0.932824146841634
# acceleration 0.42028891210165054  -0.5054194890521758 -0.5436840835009299
# model_year    0.5792671330833092 -0.34874579661359445 -0.3701641610793247
#
#                        horsepower              weight        acceleration  \
# mpg           -0.7784267838977761 -0.8317409332443344 0.42028891210165054
# cylinders      0.8429833569186568  0.8960167954533944 -0.5054194890521758
# displacement     0.89725700184347   0.932824146841634 -0.5436840835009299
# horsepower                    1.0  0.8645377375741455 -0.6891955103342376
# ...

# %%
sns.heatmap(car.corr(),cmap='RdBu',center=0,vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(origin_cyl,cmap='Blues',annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-898-2b7315f9d52b> in <module>
# ----> 1 sns.heatmap(origin_cyl,cmap='Blues',annot=True)
#
# NameError: name 'origin_cyl' is not defined
